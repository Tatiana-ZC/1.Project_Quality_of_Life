# %%
# !pip install fuzzywuzzy
# !pip install ydata-profiling
# !pip install python-Levenshtein
# !pip install ipywidgets

# %% [markdown]
# #### Importing libreries:

# %%
import numpy as np
import pandas as pd
from collections import OrderedDict
from ydata_profiling import ProfileReport
import time
import datetime
from fuzzywuzzy import process
import re
import seaborn as sns
import matplotlib.pyplot as plt

# %%
pd.set_option('display.max_columns', None)

# %% [markdown]
# # Hypotesis 3:

# %% [markdown]
# ## People are happier if they have an active life (healthier lifestyles) under the sunshine.

# %% [markdown]
# Data sources available to analyse H1:
# - Sunlight along the year
# - Causes of Death

# %% [markdown]
# #### Loading the DataFrames:

# %% [markdown]
# ### Sunlight along the year

# %% [markdown]
# **Source:** Web Scraping *Wikipedia*
#
#
# [List of cities by sunshine duration](https://en.wikipedia.org/wiki/List_of_cities_by_sunshine_duration)

# %%
import requests

url = "https://en.wikipedia.org/wiki/List_of_cities_by_sunshine_duration"
headers = {'User-Agent': 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_10_1) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/39.0.2171.95 Safari/537.36'}

response = requests.get(url, headers=headers)
response
# Out:
# <Response [200]>

# %%
from bs4 import BeautifulSoup

soup = BeautifulSoup(response.content, "html.parser")

# %%
type(soup)
# Out:
# bs4.BeautifulSoup

# %%
print(soup.prettify()) # This formats the HTML in a readable way
# Out:
# <!DOCTYPE html>
# <html class="client-nojs vector-feature-language-in-header-enabled vector-feature-language-in-main-page-header-disabled vector-feature-sticky-header-disabled vector-feature-page-tools-pinned-disabled vector-feature-toc-pinned-clientpref-1 vector-feature-main-menu-pinned-disabled vector-feature-limited-width-clientpref-1 vector-feature-limited-width-content-enabled vector-feature-custom-font-size-clientpref-1 vector-feature-appearance-enabled vector-feature-appearance-pinned-clientpref-1 vector-feature-night-mode-disabled skin-theme-clientpref-day vector-toc-available" dir="ltr" lang="en">
#  <head>
#   <meta charset="utf-8"/>
#   <title>
#    List of cities by sunshine duration - Wikipedia
#   </title>
#   <script>
# ...

# %%
# Find all <h2> tags with class "text-h5 mb-2"
soup.find_all(class_="wikitable plainrowheaders sortable jquery-tablesorter")
# Out:
# []

# %%
tables = soup.find_all(class_='wikitable plainrowheaders sortable') 
len(tables)
# Out:
# 6

# %%
tables[0]
# Out:
# <table class="wikitable plainrowheaders sortable" style="text-align:right;">
# <caption>Sunshine hours for selected cities in Africa
# </caption>
# <tbody><tr style="vertical-align:top">
# <th>Country
# </th>
# <th>City
# </th>
# <th>Jan
# </th>
# <th>Feb
# </th>
# <th>Mar
# </th>
# <th>Apr
# </th>
# <th>May
# </th>
# <th>Jun
# </th>
# <th>Jul
# </th>
# <th>Aug
# </th>
# <th>Sep
# </th>
# <th>Oct
# </th>
# <th>Nov
# </th>
# <th>Dec
# </th>
# <th>Year
# </th>
# <th>Ref.
# </th></tr>
# <tr>
# <td style="text-align:left;"><a class="mw-redirect" href="/wiki/Ivory_Coast" title="Ivory Coast">Ivory Coast</a>
# </td>
# <td style="text-align:left;"><a href="/wiki/Gagnoa" title="Gagnoa">Gagnoa</a>
# </td>
# <td style="background: #D5D500; color:#000000;;">183.0
# </td>
# <td style="background: #D4D400; color:#000000;;">180.0
# </td>
# <td style="background: #D8D800; color:#000000;;">196.0
# </td>
# <td style="background: #D6D600; color:#000000;;">188.0
# </td>
# ...

# %%
import pandas as pd

for table in tables:
    data=pd.read_html(table)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[20], line 4
#       1 import pandas as pd
#       3 for table in tables:
# ----> 4     data=pd.read_html(table)
#
# File c:\Users\TatyZC\anaconda3\envs\Intro.Anaconda\Lib\site-packages\pandas\io\html.py:1246, in read_html(io, match, flavor, header, index_col, skiprows, attrs, parse_dates, thousands, encoding, decimal, converters, na_values, keep_default_na, displayed_only, extract_links, dtype_backend, storage_options)
#    1230 if isinstance(io, str) and not any(
#    1231     [
#    1232         is_file_like(io),
#    (...)
#    1236     ]
#    1237 ):
#    1238     warnings.warn(
#    1239         "Passing literal html to 'read_html' is deprecated and "
#    1240         "will be removed in a future version. To read from a "
#    (...)
#    1243         stacklevel=find_stack_level(),
#    1244     )
# ...

# %%
#TODO Get sunshine hours by month for each city in Africa, Asia, Europe, Oceania and North and South America.

# %%
#TODO Create a table for each continent with an unique value per month for each country (average between cities).

# %%
#TODO Rank 6: Sort countries with the most hours of sunlight within the year.

# %% [markdown]
# ### Causes of Death

# %% [markdown]
# **Source:** Our World in Data
#
# [Causes of death, World, 2021](https://ourworldindata.org/grapher/annual-number-of-deaths-by-cause)
#
# _The estimated annual number of deaths from each cause._

# %%
death_causes = pd.read_csv("3.Causes_of_Death_2021.csv")

# %%
death_causes
# Out:
#        Country/area Meningitis\ndeaths • 2021 Dementia\ndeaths • 2021  \
# 0       Afghanistan                     1,974                   1,622
# 1           Albania                         7                     792
# 2           Algeria                       225                   5,591
# 3    American Samoa                         1                       7
# 4           Andorra                         0                      46
# ..              ...                       ...                     ...
# 199       Venezuela                       381                   5,701
# 200         Vietnam                       666                  19,281
# 201           Yemen                       381                   1,932
# 202          Zambia                     2,154                     772
# 203        Zimbabwe                     1,442                     671
#
#     Parkinson's disease\ndeaths • 2021  \
# 0                                  470
# 1                                  240
# ...

# %%
#TODO Sum total deaths by country

# %%
#TODO Get the percentage of deaths over total population.

# %%
#TODO Rank 7: Sort countries that have less percentage of deaths.

# %%
#TODO Index D: Ranking of countries in a combination between Rank 6 and 7.
