# %%
# !pip install fuzzywuzzy
# !pip install ydata-profiling
# !pip install python-Levenshtein
# !pip install ipywidgets

# %% [markdown]
# #### Importing libreries:

# %%
import numpy as np
import pandas as pd
from collections import OrderedDict
from ydata_profiling import ProfileReport
import time
import datetime
from fuzzywuzzy import process
import re
import seaborn as sns
import matplotlib.pyplot as plt

# %%
pd.set_option('display.max_columns', None)

# %% [markdown]
# # Hypotesis 4:

# %% [markdown]
# ## European people are happier in developed Mediterranean countries.

# %% [markdown]
# Data sources available to analyse H1:
# - Life expectancy

# %% [markdown]
# #### Loading the DataFrames:

# %% [markdown]
# ### Life expectancy

# %% [markdown]
# **Source:** *Kaggle* Datasets
#
#
# [Life expectancy & Socio-Economic (World Bank)](https://www.kaggle.com/datasets/mjshri23/life-expectancy-and-socio-economic-world-bank/data)

# %%
life_expectancy = pd.read_csv("4.Life_Expectancy.csv")

# %%
life_expectancy
# Out:
#        Country/area Meningitis\ndeaths • 2021 Dementia\ndeaths • 2021  \
# 0       Afghanistan                     1,974                   1,622
# 1           Albania                         7                     792
# 2           Algeria                       225                   5,591
# 3    American Samoa                         1                       7
# 4           Andorra                         0                      46
# ..              ...                       ...                     ...
# 199       Venezuela                       381                   5,701
# 200         Vietnam                       666                  19,281
# 201           Yemen                       381                   1,932
# 202          Zambia                     2,154                     772
# 203        Zimbabwe                     1,442                     671
#
#     Parkinson's disease\ndeaths • 2021  \
# 0                                  470
# 1                                  240
# ...

# %%
#TODO Rank 8: Sort countries with the highest Life Expectancy by country.

# %%
#TODO Index E = Rank 8
